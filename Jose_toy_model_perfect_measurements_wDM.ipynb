# %% [markdown]
# # Bayesian degeneracies
#
# In this notebook we play with the Bayesian inference from the population in order to understand if the degeneracies between cosmology and mass evolution can be broken
#
# We convert our previous code to numpyro

# %%
import numpy as np

#Numpyro and friends
import numpyro
from numpyro.infer import NUTS,MCMC
import numpyro.distributions as dist
from jax import random
from jax import jit
from jax.config import config
import jax.numpy as jnp
from jax.scipy.special import erf
import arviz as az

config.update("jax_enable_x64", True)
nChains = 1
numpyro.set_host_device_count(nChains)

#PYTHON MODULES
from constants import *
from constants_gw import *
import jgwcosmo_wDM as jgwcosmo
import jgwpop

#PLOTS
import matplotlib.pyplot as plt
import corner
import sys
dir_base=sys.path[0]
dir_out=dir_base+"/plots_cosmo_mass_evolution/"

from matplotlib.ticker import ScalarFormatter
#%config InlineBackend.figure_format = 'retina'
#plt.rc('text', usetex=True)
#plt.rc('font', family='serif')
fontSz = 15
fontsz = 13
fontssz = 11

new_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
              '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
              '#bcbd22', '#17becf']

# %% [markdown]
# ---
# Observed population

# %%
#Fiducial universe
Omk_fid = 0.00 # 0=flat


H0_fid  = 67.66     # cosmo.H(0).value #cosmology is Planck'18
zp_fid = 2.4
beta_fid = 3.4
kappa1_fid = 1.8
kappa2_fid = 5.
b_fid = 0.4
bq_fid = 0.0
r0_fid = 30.
dmMax_fid = 2.
dmMin_fid = 1.
tmp_min = 2.
tmp_max = 150.

w_fid=0
Om0_fid     = 0.30966  # cosmo.Om(0)
alpha_fid = -2.7
alpha_z_fid = 1.
f_peak_fid = 0.05
mmax_fid = 78.
mmin_fid = 10.
mu_m1_fid = 30.
sig_m1_fid = 7.
w_fid = 0.   #wDM fid = 0

# %% [markdown]
# ---
# Priors

# %%
#Priors
Om0_min, Om0_max         = 0.2,0.6   # fid~0.31
alpha_min, alpha_max     = 2.5, 2.9  # fid=-2.7
azmin, azmax             = 0.92,1.2   # fid=1
fmin, fmax               = 0.04,0.06 # fid=0.05
mmax_min, mmax_max       = 72., 82.  # fid=78
mmin_min, mmin_max       = 9.5, 10.4    # fid=10
mumin, mumax             = 10,50 # fid =30
sigmin, sigmax           = 5.5,7.8   # fid=7 **
w_min, w_max             = -0.1, 0.1 # wDM fid = 0


#w_min, w_max             = -1.5, -0.1  # w DE **********
#Omk_min, Omk_max         = -0.5,0.5    # **********
#h0_min, h0_max           = 0.4, 1.2   


kappa1_min, kappa1_max   = -4., 12.
kappa2_min, kappa2_max   = -4., 12.

b_min, b_max             = 0., 1.
beta_min, beta_max       = 0., 10.
zp_min, zp_max           = 0., 4.
gamma_min, gamma_max     = -10, 10
log10r0_min, log10r0_max = -3., 3.

# %% [markdown]
# ---

# %% [markdown]
# ---
# # 1. Fiducial population without evolution

# %%
gamma1_fid = 0.
gamma2_fid = 0.

# %%
n_samples = 1
n_detections = 5000 #increase fx. x5 times. or more. vary it etc. then plot value vs N increasing
#H0 is local- but blakholes are in high z so this is not the best method to contrain H0
# try omk0 with only positive curv expressions and see if it is fixed
#cases-H0 Omk0,?Om0
#- omk, Om0
#/ Om0, wdm
#/ Om0, wDE

# read lambda cdm model - explain how we are doing extension of that
# calculate rate for future detectors

# %% [markdown]
# ---
# ## Generate mock data

# %%
""" Inverse Sampling """
from scipy.integrate import cumtrapz
from scipy.interpolate import interp1d
def inverse_transf_sampling(cum_values,variable,n_samples):
    inv_cdf = interp1d(cum_values, variable)
    r = np.random.uniform(min(cum_values),max(cum_values),n_samples)
    return inv_cdf(r)

def mock_source_parameters(n_sources,w,H0,Om0,mmin,mmax,alpha,sig_m1,mu_m1,f_peak,zp,alpha_z,beta):
    zs = np.linspace(0.01,10.,10000)
    cdf_z = cumtrapz(jgwcosmo.diff_comoving_volume(zs,H0,Om0,w)*jgwpop.rate_z(zs,zp,alpha_z,beta)/(1+zs),zs,initial=0)
    cdf_z /= cdf_z[-1]
    
    masses = np.linspace(tmp_min,tmp_max,10000)
    cdf_m1 = cumtrapz(jgwpop.powerlaw_peak(masses,mmin,mmax,alpha,sig_m1,mu_m1,f_peak),masses,initial=0)
    # the power law of mass dist(2 peaks)
    cdf_m1 /= cdf_m1[-1]

    z_mock = inverse_transf_sampling(cdf_z,zs,n_sources)
    m1_mock = inverse_transf_sampling(cdf_m1,masses,n_sources)
    m2_mock = np.random.uniform(mmin,m1_mock,n_sources)
    #### dL_mock = jgwcosmo.dL_approx(z_mock,H0,Om0)
    #### = REPLACED APPROX FUNCTIONS
    dL_mock = jgwcosmo.d_L(z_mock,H0,Om0,w)
    m1z_mock = (1 + z_mock) * m1_mock
    m2z_mock = (1 + z_mock) * m2_mock
    return m1z_mock, m2z_mock, dL_mock

# %% [markdown]
# For the perfect measurement we only have one sample directly associated to the mock event

# %%
n_sources = n_detections

m1z_mock_CE, m2z_mock_CE, dL_mock_CE = mock_source_parameters(n_sources,w_fid,H0_fid,Om0_fid,mmin_fid,mmax_fid,alpha_fid,sig_m1_fid,mu_m1_fid,f_peak_fid,zp_fid,alpha_z_fid,beta_fid)

#THis is not really necessary because only 1 sample...but was introduced for the more general case
m1z_mock_samples_CE = np.zeros((n_detections,n_samples))
m2z_mock_samples_CE = np.zeros((n_detections,n_samples))
dL_mock_samples_CE = np.zeros((n_detections,n_samples))
jacob_mock_samples_CE = np.ones((n_detections,n_samples))
for i in range(n_detections):
    m1z_mock_samples_CE[i,:], m2z_mock_samples_CE[i,:], dL_mock_samples_CE[i,:] = m1z_mock_CE[i], m2z_mock_CE[i], dL_mock_CE[i]

# %% [markdown]
# ---
# ## Likelihood

# %%
def log_Rz(z,r0,zp,alpha,beta):
    c0 = jnp.log1p((1. + zp)**(-alpha-beta))
    num = (1.+z)**alpha
    den = 1. + ((1.+z)/(1.+zp))**(alpha+beta)
    return jnp.log(r0) + c0  + alpha*jnp.log1p(z) - jnp.log1p(jnp.power((1.+z)/(1.+zp),(alpha+beta)))

def log_cosmo(z,H0,Om0,w):
    ####
    dL = jgwcosmo.d_L(z,H0,Om0,w)#Mpc
    Ez_i = jgwcosmo.Ez_inv(z,Om0,w)
    D_H = (Clight/1e3)  / H0 #Mpc
    
    logdiff_comoving_volume = jnp.log(1.0e-9) + jnp.log(4*jnp.pi) + 2*jnp.log(dL) +jnp.log(D_H) +jnp.log(Ez_i)-2*jnp.log1p(z)
    ddLdz = dL/(1.+z) + (1. + z)*D_H * Ez_i #Mpc 
    logJacobian = jnp.log(jnp.abs(ddLdz))#Jac has absolute value 
    return logdiff_comoving_volume - jnp.log1p(z) - logJacobian 

def logNdet_events(m1,m2,z,p_draw,w,H0,Om0,r0,Tobs,zp,alpha_z,beta,mmin,mmax,alpha,sig_m1,mu_m1,f_peak,bq,Nsamples):
    #input data (N,M): N detections x M samples
    log_pm1 = jnp.log(jgwpop.powerlaw_peak(m1,mmin,mmax,alpha,sig_m1,mu_m1,f_peak)) - jnp.log1p(z) #(1+z) from Jac prior
    log_pm2 = 0 #NOT adding this at the moment #jnp.log(jgwpop.powerlaw_smooth(m2,mmin,m1,bq)) - jnp.log1p(z) #(1+z) from Jac prior
    log_pm = log_pm1 + log_pm2
    logcosmo = log_cosmo(z,H0,Om0,w)
    logRzs = log_Rz(z,r0,zp,alpha_z,beta) + jnp.log(Tobs)
    log_dN = log_pm + logcosmo + logRzs - jnp.log(p_draw)
    
    m = 0 #jnp.transpose(jnp.transpose(jnp.max(log_dN,axis=1))*jnp.ones((Nsamples,1)))
    return jnp.sum(m + jnp.log(jnp.sum(jnp.exp(log_dN-m),axis=1)) - jnp.log(Nsamples))

# %% [markdown]
# _Possible improvements_
#
# - Only call dL once by computing the redshift normalization aty the same time
# - 2D normaliztion for masses, 3D for mass evolution?

# %%
@jit
def log_lik(w,h0,Om0,mmin,mmax,alpha,mu_m1,sig_m1,f_peak,alpha_z,zp,beta):
    #Fixed parameters
    r0 = 1.0 # 10.**log10r0
    H0 = h0*100
    Tobs = 1.
    bq = bq_fid # We are not using m2 sitribution
    
    Nobs, Nsamples = jnp.shape(m1z_mock_samples_CE)
    
    D_H = (Clight/1.0e3)  / H0 #Mpc
    ####
    #m1_mock, m2_mock, z_mock = jgwcosmo.detector_to_source_frame_approx_dLdH(m1z_mock_samples_CE,m2z_mock_samples_CE,dL_mock_samples_CE/D_H,Om0,zmin=1e-3,zmax=100)
    m1_mock, m2_mock, z_mock = jgwcosmo.detector_to_source_frame(m1z_mock_samples_CE, m2z_mock_samples_CE, dL_mock_samples_CE,H0,Om0,w,zmin=1e-3,zmax=100)
    #print('m',m1_mock, m2_mock, z_mock)                        #(m1z, m2z, dL, H0, Om0, w, zmin=1e-3,zmax=100)
    #Log_lik Events
    p_draw = jacob_mock_samples_CE
    loglik_E = logNdet_events(m1_mock,m2_mock,z_mock,p_draw,w,H0,Om0,r0,Tobs,zp,alpha_z,beta,mmin,mmax,alpha,sig_m1,mu_m1,f_peak,bq,Nsamples)

    zs_norm = jnp.linspace(0.01,10,1000) 
    ####
    dn_detec = jgwpop.rate_z(zs_norm,zp,alpha_z,beta)*jgwcosmo.diff_comoving_volume(zs_norm,H0,Om0,w)/(1.+zs_norm)   
    norm_z = jnp.trapz(dn_detec,zs_norm)
    loglik_E -= Nobs*jnp.log(norm_z)
    #print('loglik_E',loglik_E)
    m1s_norm = jnp.linspace(tmp_min,tmp_max,1000)    
    norm_m1 = jnp.trapz(jgwpop.powerlaw_peak(m1s_norm,mmin,mmax,alpha,sig_m1,mu_m1,f_peak),m1s_norm)
    loglik_E -= Nobs*jnp.log(norm_m1)
    
    #Selection effects
    loglik_N = 0.
    
    return loglik_N + loglik_E


#log_lik(0, 0.8139396015300265, 0.212839082203157, 16.66972424776207, 61.672686222534224, 1.5071812823795439, 50.81505348874913, 4.61719304924998, 0.8152541257648079, 1.5994087806939, 2.4, 3.4)

# %%
def log_probability():
    
    #Priors
    w = numpyro.sample("w",dist.Uniform(w_min,w_max))
    #Omk = 0.01 #numpyro.sample("Omk0",dist.Uniform(Omk_min,Omk_max))
    h0 = 67.66/100 #numpyro.sample("h0",dist.Uniform(h0_min,h0_max))
    Om0 = numpyro.sample("Om0",dist.Uniform(Om0_min,Om0_max))
    mmin = numpyro.sample("mmin",dist.Uniform(mmin_min,mmax_max))
    mmax = numpyro.sample("mmax",dist.Uniform(mmax_min,mmax_max))
    alpha = numpyro.sample("alpha",dist.Normal(alpha_min, alpha_max)) #0,5
    mu_m1 = numpyro.sample("mu_m1",dist.Uniform( mumin, mumax)) #20,60
    sig_m1 = numpyro.sample("sig_m1",dist.Uniform(sigmin, sigmax)) #1,10
    f_peak = numpyro.sample("f_peak",dist.Uniform(fmin, fmax))#0,1
    alpha_z = numpyro.sample("alpha_z",dist.Uniform(azmin, azmax))#numpyro.deterministic('alpha_z',alpha_z_fid)#numpyro.sample("alpha_z",dist.Normal(0,5))
    #Fixed
    zp = zp_fid #numpyro.deterministic('zp',zp_fid)
    beta = beta_fid #numpyro.deterministic('beta',beta_fid)
    #bq = numpyro.sample("bq",dist.Normal(0,5)) #when fitting m_2
    
    #Likelihood
    numpyro.factor("logp",log_lik(w,h0,Om0,mmin, mmax,alpha,mu_m1,sig_m1,f_peak,alpha_z,zp,beta))

# %%
rng_key = random.PRNGKey(2)
rng_key,rng_key_ = random.split(rng_key)

# %%
# Set up NUTS sampler over our likelihood
kernel = NUTS(log_probability)

#mcmc = MCMC(kernel,num_warmup=500,num_samples=2000,num_chains=nChains,chain_method='parallel')
##num_warmup=300,num_samples=3000
mcmc = MCMC(kernel,num_warmup=100,num_samples=200,num_chains=nChains,chain_method='parallel')

# %%
mcmc.run(rng_key_)#, init_params=jnp.array([H0_fid/100, mmin_fid,mmax_fid,-2.7,5,30.,0.05])
mcmc.print_summary()
samples = mcmc.get_samples()

print('Fiducial values:')
print('H0=',H0_fid,', Om0=',Om0_fid)
print('w=',w_fid,'alpha=',alpha_fid,', bq=',bq_fid,', f_peak=',f_peak_fid,', mmax=',mmax_fid,', mmin=',mmin_fid,', mu_m1=',mu_m1_fid,', sig_m1=',sig_m1_fid)
print('alpha_z=',alpha_z_fid,', zp=',zp_fid,', beta=',beta_fid)

print('n_sources')
# Out:
# warmup:  18%|▏| 54/300 [04:43<51:19, 12.52s/it, 191 steps of size 2.54e-02. acc.

# %%
az.plot_trace(mcmc)#, compact=True)
#plt.tight_layout()
#plt.savefig('chain_wDMfixH_2500new.png')
plt.show()

# %%
fig = corner.corner(
    samples,quantiles=[0.16, 0.5, 0.84],smooth=1,label_kwargs={"fontsize": 14,"color":'silver'}, #labels=labels,
                       show_titles=True,title_kwargs={"fontsize": 14,"color":'white'},color='silver',
    truths=[Om0_fid,alpha_fid,alpha_z_fid,f_peak_fid,mmax_fid,mmin_fid,mu_m1_fid,sig_m1_fid,w_fid],#, truths=[H0_fid/100,alpha_ml, zp_ml]
truth_color='silver',no_fill_contours=True );
plt.tick_params(color='silver')
#corner.overplot_lines(fig, [alpha_fid,alpha_z_fid,f_peak_fid,mmax_fid,mmin_fid,mu_m1_fid,Om0_fid,sig_m1_fid,w_fid], marker="s",color="C1")
#corner.overplot_points(fig,np.array([w_fid,Om0_fid,alpha_fid,alpha_z_fid,f_peak_fid,mmax_fid,mmin_fid,mu_m1_fid,sig_m1_fid]) , marker="s", color="C2")
#plt.savefig('PICSnew/corner_wDM_1200_'+str(n_detections)+'Pts.pdf',transparent=True)
plt.show()

# %%
#black png version
fig = corner.corner(
    samples,quantiles=[0.16, 0.5, 0.84],#, labels=labels
                    smooth=1,label_kwargs={"fontsize": 14}, #labels=labels,
                       show_titles=True,title_kwargs={"fontsize": 14},
    #truths=[Om0_fid,alpha_fid,alpha_z_fid,f_peak_fid,H0_fid/100,mmax_fid,mmin_fid,mu_m1_fid,sig_m1_fid],#, truths=[H0_fid/100,alpha_ml, zp_ml]
 plot_contours=False,no_fill_contours=True 
                      #, truths=[H0_fid/100,alpha_ml, zp_ml]
);
plt.savefig('PICSnew/corner_wDM_1200_'+str(n_detections)+'Pts.png',transparent=True)
#plt.savefig('PICSnew/corner_Om0H0_2500_'+str(n_detections)+'Pts.png',transparent=True)
plt.show()

# %%
ndim, nsamples = 4, 50000
np.random.seed(1234)
data1 = np.random.randn(ndim * 4 * nsamples // 5).reshape(
    [4 * nsamples // 5, ndim]
)

mean = 4 * np.random.rand(ndim)
data2 = mean[None, :] + np.random.randn(ndim * nsamples // 5).reshape(
    [nsamples // 5, ndim]
)
print(data1.shape)
Samples = np.vstack([data1, data2])

figure = corner.corner(Samples,hist_kwargs={transparent:True})
# Out:
# (40000, 4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [147], in <cell line: 14>()
#      11 print(data1.shape)
#      12 Samples = np.vstack([data1, data2])
# ---> 14 figure = corner.corner(Samples,hist_kwargs={transparent:True})
#
# NameError: name 'transparent' is not defined

# %%
#dict = {'Python' : '.py', 'C++' : '.cpp', 'Java' : '.java'}

# open file for writing
f = open("samples_wDM_15k.txt","w")

# write file
f.write( str(samples) )

# close file
f.close()

# %%
f2 = open("samples_wDM_5k.txt","r")


corner.corner(np.array(f2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [159], in <cell line: 4>()
#       1 f2 = open("samples_wDM_5k.txt","r")
# ----> 4 corner.corner(np.array(f2))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/corner/arviz_corner.py:90, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#      88         data = data[None, :, :]
#      89     elif data.ndim != 3:
# ---> 90         raise ValueError("invalid input dimensions")
#      91 if data.__class__.__name__ == "DataFrame":
#      92     logging.warning(
#      93         "Pandas support in corner is deprecated; use ArviZ directly"
#      94     )
#
# ValueError: invalid input dimensions

# %%
data1=samples['w'].reshape(1)
data2=samples['Om0'].reshape(1)
subsamples = np.vstack([data1, data2])
f=corner.corner(
    subsamples,quantiles=[0.16, 0.5, 0.84],smooth=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [138], in <cell line: 1>()
# ----> 1 data1=samples['w'].reshape(1)
#       2 data2=samples['Om0'].reshape(1)
#       3 subsamples = np.vstack([data1, data2])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py:145, in _reshape(a, order, *args)
#     143 newshape = _compute_newshape(a, args[0] if len(args) == 1 else args)
#     144 if order == "C":
# --> 145   return lax.reshape(a, newshape, None)
#     146 elif order == "F":
#     147   dims = list(range(a.ndim)[::-1])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py:857, in reshape(operand, new_sizes, dimensions)
#     854 else:
#     855   dyn_shape, static_new_sizes = _extract_tracers_dyn_shape(new_sizes)
# --> 857   return reshape_p.bind(
#     858     operand, *dyn_shape, new_sizes=tuple(static_new_sizes),
#     859     dimensions=None if dims is None or same_dims else dims)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:380, in Primitive.bind(self, *args, **params)
#     377 def bind(self, *args, **params):
#     378   assert (not config.jax_enable_checks or
#     379           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 380   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:383, in Primitive.bind_with_trace(self, trace, args, params)
#     382 def bind_with_trace(self, trace, args, params):
# --> 383   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     384   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:790, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     789 def process_primitive(self, primitive, tracers, params):
# --> 790   return primitive.impl(*tracers, **params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:132, in apply_primitive(prim, *args, **params)
#     130 try:
#     131   in_avals, in_shardings = util.unzip2([arg_spec(a) for a in args])
# --> 132   compiled_fun = xla_primitive_callable(
#     133       prim, in_avals, OrigShardings(in_shardings), **params)
#     134 except pxla.DeviceAssignmentMismatchError as e:
#     135   fails, = e.args
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/util.py:284, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     282   return f(*args, **kwargs)
#     283 else:
# --> 284   return cached(config._trace_context(), *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/util.py:277, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     275 @functools.lru_cache(max_size)
#     276 def cached(_, *args, **kwargs):
# --> 277   return f(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:223, in xla_primitive_callable(prim, in_avals, orig_in_shardings, **params)
#     221     return out,
#     222 donated_invars = (False,) * len(in_avals)
# --> 223 compiled = _xla_callable_uncached(
#     224     lu.wrap_init(prim_fun), prim.name, donated_invars, False, in_avals,
#     225     orig_in_shardings)
#     226 if not prim.multiple_results:
#     227   return lambda *args, **kw: compiled(*args, **kw)[0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:250, in _xla_callable_uncached(fun, name, donated_invars, keep_unused, in_avals, orig_in_shardings)
#     248 def _xla_callable_uncached(fun: lu.WrappedFun, name, donated_invars,
#     249                            keep_unused, in_avals, orig_in_shardings):
# --> 250   computation = sharded_lowering(
#     251       fun, name, donated_invars, keep_unused, True, in_avals, orig_in_shardings,
#     252       lowering_platform=None)
#     253   return computation.compile().unsafe_call
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:242, in sharded_lowering(fun, name, donated_invars, keep_unused, inline, in_avals, in_shardings, lowering_platform)
#     237 in_shardings = [UNSPECIFIED if i is None else i for i in in_shardings]  # type: ignore
#     239 # Pass in a singleton `UNSPECIFIED` for out_shardings because we don't know
#     240 # the number of output avals at this stage. lower_sharding_computation will
#     241 # apply it to all out_avals.
# --> 242 return pxla.lower_sharding_computation(
#     243     fun, 'jit', name, in_shardings, UNSPECIFIED, donated_invars,
#     244     tuple(in_avals), keep_unused=keep_unused, inline=inline, always_lower=False,
#     245     devices_from_context=None, lowering_platform=lowering_platform)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2014, in lower_sharding_computation(fun_or_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, always_lower, devices_from_context, lowering_platform)
#    2008 # 1. Trace to jaxpr and preprocess/verify it
#    2009 auto_spmd_lowering = (
#    2010     check_if_any_auto(in_shardings) if is_unspecified(out_shardings) else
#    2011     check_if_any_auto(it.chain.from_iterable([in_shardings, out_shardings])))  # type: ignore
#    2013 (closed_jaxpr, global_in_avals, global_out_avals, donated_invars,
# -> 2014  kept_var_idx, name_stack) = _trace_to_jaxpr_and_dce(
#    2015     fun_or_jaxpr, global_in_avals, api_name, fun_name, keep_unused,
#    2016     donated_invars, auto_spmd_lowering)
#    2017 jaxpr = closed_jaxpr.jaxpr
#    2018 in_shardings = tuple(s for i, s in enumerate(in_shardings) if i in kept_var_idx)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1810, in cache_wrap.<locals>.wrapped(f, *args, **kwargs)
#    1808 def wrapped(f, *args, **kwargs):
#    1809   if isinstance(f, lu.WrappedFun):
# -> 1810     return _wrapped_with_lu_cache(f, *args, **kwargs)
#    1811   else:
#    1812     return _wrapped_with_weakref_lru_cache(f, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py:345, in cache.<locals>.memoized_fun(fun, *args)
#     343   fun.populate_stores(stores)
#     344 else:
# --> 345   ans = call(fun, *args)
#     346   cache[key] = (ans, fun.stores)
#     348 return ans
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1825, in _trace_to_jaxpr_and_dce(fun_or_jaxpr, global_in_avals, api_name, fun_name, keep_unused, donated_invars, auto_spmd_lowering)
#    1821 if isinstance(fun_or_jaxpr, lu.WrappedFun):
#    1822   with dispatch.log_elapsed_time(
#    1823       "Finished tracing + transforming {fun_name} in {elapsed_time} sec",
#    1824       fun_name=str(name_stack), event=dispatch.JAXPR_TRACE_EVENT):
# -> 1825     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_final(
#    1826         fun_or_jaxpr, global_in_avals)
#    1827 else:
#    1828   assert isinstance(fun_or_jaxpr, core.ClosedJaxpr)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:2228, in trace_to_jaxpr_final(fun, in_avals, debug_info, keep_inputs)
#    2226   main.jaxpr_stack = ()  # type: ignore
#    2227   with core.new_sublevel():
# -> 2228     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2229       fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2230   del fun, main
#    2231 return jaxpr, out_avals, consts
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:2172, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2170 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2171 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2172 ans = fun.call_wrapped(*in_tracers_)
#    2173 out_tracers = map(trace.full_raise, ans)
#    2174 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py:188, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 gen = gen_static_args = out_store = None
#     187 try:
# --> 188   ans = self.f(*args, **dict(self.params, **kwargs))
#     189 except:
#     190   # Some transformations yield from inside context managers, so we have to
#     191   # interrupt them before reraising the exception. Otherwise they will only
#     192   # get garbage-collected at some later time, running their cleanup tasks
#     193   # only after this exception is handled, which can corrupt the global
#     194   # state.
#     195   while stack:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:217, in xla_primitive_callable.<locals>.prim_fun(*args)
#     216 def prim_fun(*args):
# --> 217   out = prim.bind(*args, **params)
#     218   if prim.multiple_results:
#     219     return out
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:380, in Primitive.bind(self, *args, **params)
#     377 def bind(self, *args, **params):
#     378   assert (not config.jax_enable_checks or
#     379           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 380   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:383, in Primitive.bind_with_trace(self, trace, args, params)
#     382 def bind_with_trace(self, trace, args, params):
# --> 383   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     384   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:1854, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1852 def process_primitive(self, primitive, tracers, params):
#    1853   if primitive in custom_staging_rules:
# -> 1854     return custom_staging_rules[primitive](self, *tracers, **params)
#    1855   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py:3316, in _reshape_staging_rule(trace, x, new_sizes, dimensions, *dyn)
#    3314 params = dict(new_sizes=new_sizes, dimensions=dimensions)
#    3315 if not dyn:
# -> 3316   return trace.default_process_primitive(reshape_p, (x,), params)
#    3317 av = core.DShapedArray(_merge_dyn_shape(new_sizes, dyn), x.dtype, x.weak_type)
#    3318 return _dyn_shape_staging_rule(trace, reshape_p, av, x, *dyn, **params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:1859, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1857 def default_process_primitive(self, primitive, tracers, params):
#    1858   avals = [t.aval for t in tracers]
# -> 1859   out_avals, effects = primitive.abstract_eval(*avals, **params)
#    1860   out_avals = [out_avals] if not primitive.multiple_results else out_avals
#    1861   source_info = source_info_util.current()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/core.py:416, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     415 def abstract_eval_(*args, **kwargs):
# --> 416   return abstract_eval(*args, **kwargs), no_effects
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/lax/utils.py:63, in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, named_shape_rule, *avals, **kwargs)
#      61   return core.ConcreteArray(out.dtype, out, weak_type=weak_type)
#      62 elif least_specialized is core.ShapedArray:
# ---> 63   return core.ShapedArray(shape_rule(*avals, **kwargs),
#      64                           dtype_rule(*avals, **kwargs), weak_type=weak_type,
#      65                           named_shape=named_shape_rule(*avals, **kwargs))
#      66 elif least_specialized is core.DShapedArray:
#      67   shape = shape_rule(*avals, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py:3262, in _reshape_shape_rule(operand, new_sizes, dimensions)
#    3259 if (not config.jax_dynamic_shapes and
#    3260     not core.same_shape_sizes(np.shape(operand), new_sizes)):
#    3261   msg = 'reshape total size must be unchanged, got new_sizes {} for shape {}.'
# -> 3262   raise TypeError(msg.format(new_sizes, np.shape(operand)))
#    3263 if dimensions is not None:
#    3264   if set(dimensions) != set(range(np.ndim(operand))):
#
# TypeError: reshape total size must be unchanged, got new_sizes (1,) for shape (2000,).

# %%
mcmc.run(rng_key_)#, init_params=jnp.array([H0_fid/100, mmin_fid,mmax_fid,-2.7,5,30.,0.05])
mcmc.print_summary()
samples2 = mcmc.get_samples()

print('Fiducial values:')
print('H0=',H0_fid,', Om0=',Om0_fid)
print('w=',w_fid,'alpha=',alpha_fid,', bq=',bq_fid,', f_peak=',f_peak_fid,', mmax=',mmax_fid,', mmin=',mmin_fid,', mu_m1=',mu_m1_fid,', sig_m1=',sig_m1_fid)
print('alpha_z=',alpha_z_fid,', zp=',zp_fid,', beta=',beta_fid)
# Out:
# sample: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2500/2500 [1:15:21<00:00,  1.81s/it, 31 steps of size 9.74e-02. acc. prob=0.90]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#        Om0      0.39      0.05      0.40      0.32      0.49    500.45      1.00
#      alpha     -2.67      0.06     -2.67     -2.75     -2.57    883.67      1.00
#    alpha_z      1.06      0.07      1.07      0.95      1.19    807.96      1.00
#     f_peak      0.05      0.00      0.05      0.05      0.06   1067.11      1.00
#       mmax     76.93      1.28     76.82     74.86     79.06    830.57      1.00
#       mmin      9.83      0.08      9.83      9.71      9.97    578.09      1.00
#      mu_m1     29.90      0.35     29.91     29.29     30.44    640.33      1.00
#     sig_m1      6.53      0.22      6.52      6.17      6.88   1163.31      1.00
#          w     -0.05      0.03     -0.05     -0.10     -0.01    526.78      1.00
#
# Number of divergences: 0
# Fiducial values:
# H0= 67.66 , Om0= 0.30966
# w= 0.0 alpha= -2.7 , bq= 0.0 , f_peak= 0.05 , mmax= 78.0 , mmin= 10.0 , mu_m1= 30.0 , sig_m1= 7.0
# alpha_z= 1.0 , zp= 2.4 , beta= 3.4

# %%
 

az.plot_trace(mcmc)#, compact=True)
#plt.tight_layout()
#plt.savefig('chain_wDMfixH_2500new.png')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))

m1_grid = np.linspace(2,150,1000)

random_inds = np.random.choice(np.arange(samples['mmax'].size),size=500)
for i in random_inds:
    
    p_m1 = jgwpop.powerlaw_peak(m1_grid,
                            samples['mmin'][i],
                           samples['mmax'][i],
                           samples['alpha'][i],
                            samples['sig_m1'][i],
                            samples['mu_m1'][i],
                            samples['f_peak'][i])
    p_m1 /= np.trapz(p_m1,m1_grid)
    
    ax.plot(m1_grid,p_m1,color='black',lw=0.5,alpha=0.5)

massess = np.linspace(2,150,1000)
pm_true = jgwpop.powerlaw_peak(massess,mmin_fid,mmax_fid,alpha_fid,sig_m1_fid,mu_m1_fid,f_peak_fid)
pm_true /= jnp.trapz(pm_true,massess)

ax.plot([],'k',alpha=0.5,label='Samples')
ax.semilogy(massess,pm_true)#,label='True')    

np.save('masses.npy',masses)
np.save('pmtrue.npy',pm_true)
ax.set_yscale('log')
ax.set_ylim(1e-5,1)
ax.set_xlim(0,100)
plt.legend()
#plt.savefig('mass_wfixH_2500.png')
plt.show()

# %%
fig = corner.corner(
    samples2,quantiles=[0.16, 0.5, 0.84],#, labels=labels
                       show_titles=True,fontsize=fontsz,
    truths=[w_fid,Om0_fid,alpha_fid,alpha_z_fid,f_peak_fid,mmax_fid,mmin_fid,mu_m1_fid,sig_m1_fid]#, truths=[H0_fid/100,alpha_ml, zp_ml]
);
#plt.savefig('corner_wDM_2500stp_10kPts.png')
plt.show()

# %% [markdown]
# ## Checking the tension with injected value

# %%
def dist_12_gauss(phases_1,truths):
    mean_1 = np.mean(phases_1,axis=0)
    mean_2 = truths
    Dphi_12 = mean_1 - mean_2

    
    cov_1 = np.cov(phases_1.T)
    cov_2 = 0.
    
    c12_inv = np.linalg.inv(cov_1 + cov_2)
    
    return np.sqrt(np.matmul(Dphi_12,np.matmul(c12_inv,Dphi_12)))

# %%
truths=np.array([Om0_fid,alpha_fid,alpha_z_fid,f_peak_fid,H0_fid/100,mmax_fid,mmin_fid,mu_m1_fid,sig_m1_fid])

# %%
dist_12_gauss(samples,truths)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 dist_12_gauss(samples,truths)
#
# Input In [19], in dist_12_gauss(phases_1, truths)
#       1 def dist_12_gauss(phases_1,truths):
# ----> 2     mean_1 = np.mean(phases_1,axis=0)
#       3     mean_2 = truths
#       4     Dphi_12 = mean_1 - mean_2
#
# File <__array_function__ internals>:5, in mean(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440, in mean(a, axis, dtype, out, keepdims, where)
#    3437     else:
#    3438         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3440 return _methods._mean(a, axis=axis, dtype=dtype,
#    3441                       out=out, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:167, in _mean(a, axis, dtype, out, keepdims, where)
#     163 arr = asanyarray(a)
#     165 is_float16_result = False
# --> 167 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     168 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     169     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:76, in _count_reduce_items(arr, axis, keepdims, where)
#      74     items = nt.intp(1)
#      75     for ax in axis:
# ---> 76         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      77 else:
#      78     # TODO: Optimize case when `where` is broadcast along a non-reduction
#      79     # axis and full sum is more excessive than needed.
#      80
#      81     # guarded to protect circular imports
#      82     from numpy.lib.stride_tricks import broadcast_to
#
# AxisError: axis 0 is out of bounds for array of dimension 0

# %%
len(samples[0,:])

# %%
samples
